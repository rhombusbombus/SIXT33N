# %% [markdown]
# # Lab 1: Introduction to Simulation
# ### EECS 16B: Designing Information Devices and Systems II, Spring 2022
#
# Updated by Steven Lu, Megan Zeng, Bozhi Yin (2022)
#
# stevenl@berkeley.edu, zengmegan@berkeley.edu, bozhi_yin@berkeley.edu
#
# Updated by Steven Lu, Kaitlyn Chan, Yi-Hsuan Shih (2021)
#
# stevenl@berkeley.edu, kaitlynjchan@berkeley.edu, yihsuan@berkeley.edu
#
# Updated by Hossein Najafi (2021)
#
# hossein_najafi@berkeley.edu
#
# Updated by Rafael Calleja (2020)
#
# rafael.calleja@berkeley.edu
#
# Updated by Miki Lustig (2020)
#
# -----

# %% [markdown]
# <a id='part0'></a>

# %% [markdown]
# <a id='part0'></a>
# # <span style="color:navy">Part 0: Introduction </span>
# -----

# %% [markdown]
# Welcome to EECS 16B Labs! In engineering, it is very important that you plan and design your product before you start building it. The same is the case with circuits and hardware devices. Therefore, to emphasize design skills, we introduce you to a web-based tool, Tinkercad, where you can plan, design and simulate your circuits before you build them in reality.

# %% [markdown]
# <center>
#     <img width="400px" src="images/2nd.gif">
# </center>
# <center> Students who read all the instructions carefully vs those who don't </center>
#
# ## Materials:
# - Lab syllabus
# - Lab notes
# - Getting Started with Tinkercad Guide
# - (Headphones)
#
# ## Tasks:
#
# ### Review
#
# [Lab Syllabus](https://www.eecs16b.org/labs/EECS16B_Lab_Syllabus_SP22.pdf)
#
# [Lab Note 0](https://www.eecs16b.org/labs/notes/lab_note0.pdf)
#
# [Lab Note 1](https://drive.google.com/file/d/1cQwDJf1Pql55otgx-SFpAydTaaO3jsRz/view?usp=sharing)
#
# - **Review the lab syllabus and the lab notes.** Every lab will come with notes that provide a technical review of the concepts covered in lab as well as theoretical connections. **You should read the notes before your lab section.** The notes serve as review and may help you as a reference during section.
#
# ### Pre-Lab
#
# ### Complete the pre-lab assignment before attempting to do the lab. For all students, submit your answers to the Gradescope assignment "Pre-Lab 1: Introduction to Simulation." Pre-Lab 1 is due on Sunday, January 23 at 11:59pm. No late submissions will be accepted.
#
#
#
# ## <span style="color:#ba190f"> DO NOT include units when submitting your answers on Gradescope! ONLY include the numerical value rounded to the number of decimal places specified in each question, in units specified in the question. DO NOT include letters, words, etc. If a question involves entering an answer that is not a numerical value, the format of the answer will be clearly specified in that question.

# %% [markdown]
# <a id='part1'></a>
# # <span style="color:navy">Part 1: Tinkercad </span>
# -----

# %% [markdown]
# [Getting Started with Tinkercad](https://drive.google.com/file/d/1tRCAksOrfsP-LwB_u_fCEGwiYVqTjAai/view?usp=sharing)
#
# - Walk through the Tinkercad introduction and familiarize yourself with the software.
#
# Tinkercad is a virtual tool you can use to build and simulate circuits with various different components. It's a useful tool for prototyping circuits before building them physically, allowing you to plan and test the placement of parts and wires. Tinkercad uses some elements and components that may be different from the parts we use in the hands-on kit, which we'll point out to you, but be mindful of this when comparing Tinkercad circuits and our physical circuits.
#
# To get familiar with using Tinkercad, op-amps, and microcontrollers, we will start by creating a simple op-amp buffering circuit with LED lighting driven by a square wave that is generated by the Arduino microcontroller.
#
#
# ## Starter Circuit
#
# Make sure you have created a Tinkercad account, the steps to which are in the Getting Started with Tinkercad guide.
#
# Open the starter circuit, which can be found at: [Lab 1 Starter Circuit](https://www.tinkercad.com/things/k4IUwmOt8Cl)
#
# (Virtual) Materials:
# - Breadboard
# - 1 DC Power Supply
# - 1 capacitor
# - 8 resistors
# - 4 LEDs
# - Arduino (similar to the MSP430 Launchpad used in EECS 16AB hardware labs)
# - Multimeters
# - 2 Op-amps
#
#
# ### Breadboard and layout
# To help you organize, look at the figure below. It shows the diagram of the board, and places for utilizing important components and reserved rails.
#
# <center>
#     <img width="700px" src="images/Tinker_layout_V1.png">
# </center>
#
# We will organize the breadboard in the following way:
#
# - The top and bottom + power rails$*$ will be 5V, while the - rails will be GND.
# - Block A35-J38 and A15-J18 will be reserved for the chip op-amp 1 and op-amp 2, respectively. We will explain the pinout and wire routing later. Chips like the op-amp MUST straddle the "notch" (the trench stretching the length of the breadboard). This is so you don't accidentally short the legs on opposite sides of the chip together.
# - Column 37F-37J is the pin where the signal from the microcontroller (Pin 13) will be connected to.
#
# $*$__The decoupling capacitor placed between power rails and ground is used to remove AC noise from the supply and help stablize the voltage of the power rails relative to ground (more on this in future labs later on in the course).__
#
# $*$__The top and bottom rows are linked horizontally all the way across. The other holes are linked vertically in blocks of 5 with no link across the centre.__
#
# ### Circuit Guidelines
# #### General Circuit Rules
# - Make sure you use consistent colors for ground, power voltages, etc. __Black is usually reserved for GND, and red for power__.
# - Try not to have any excessively long wires; shorten them so that it's easier to follow and debug later.
#
# #### Tinkercad Tips
# - Pay attention to how the two supply multimeters are connected, and connect the third unconnected meter appropriately to measure the signal of interest.
# - For easier readability of your layout, when creating wires, it is possible to add bends by "clicking their path". Try to avoid crossing wires as much as you can for better visualization, and use different colors for different signals if possible.
# - DO NOT connect multiple wires or component legs to the same hole. Tinkercad lets you do this, but this is physically impossible to do on a real breadboard, so do not do this.
# - Make sure your components (like resistors) go into holes on the breadboard, and DO NOT have any legs dangling in empty space. Tinkercad will let you connect floating components, but you can't physically do this with real hardware, so don't do this.
#
# #### Circuit Power Rails
# - The + and - rails are reserved for power and GND, respectively. Avoid connecting any other signals to those rails.
# - Make sure all voltage supplies have the same reference voltage. They should all have their negative terminals connected to the negative power rail (-), which is GND.
# - ALWAYS connect at least one of the GND pins on microcontrollers (e.g. Arduinos and Launchpads) to the GND rail.
# - The + and - long rails on the sides of the breadboards are not connected to their corresponding rail on the other side. Make sure to ALWAYS connect your - rails so that both sides of the breadboard have easy access to GND. Only connect your + rails when you want them to carry the same voltage.
#
# #### LEDs are polarized!
# - Note that LEDs have polarity, meaning the direction you plug it into the circuit matters.
# - __The anode (+) is the longer/crooked leg of the LED, while the cathode (-) is the shorter/straight leg of the LED__.
# - If you reverse the direction of the LED, the current will not be able to flow and the LED will not light up.
#
# <center>
# <img width='300px'
# src="images/diode.png">
# </center>
#
# ### Task 1:
#
# #### Wiring the op-amp as a buffer
# Tinkercad simulates the [LM741](http://www.learningaboutelectronics.com/Articles/LM741-op-amp-pinout-connections) operational amplifier. It is an 8 legged component with the pinout shown below:
#
# <center>
#     <img width="400px" src="images/LM741_pinout_updated.png">
# </center>
#
# You can ignore the Offset Null and NC pins on the op amp.
#
# In Tinkercad, the op-amp power rails are called ${\text{Power+}}$ and ${\text{Power-}}$, which we refer to as $V_{\text{dd}}$ and $V_{\text{ss}}$ in class, respectively. The op-amp inputs are called ${\text{In+}}$ and ${\text{In-}}$, which we refer to as $V{\text{+}}$ and $V{\text{-}}$ in class, respectively. In the schematic below, $V{\text{+}}$ is equal to $V_{\text{in}}$.
#
# You can look at the notch symbol of op amp in Tinkercad to figure out the orientation of the device and pin location. Or the pin name will show up if you put your mouse on the pin of the op amp. We also add several annotations in the starter circuit to make it easy for you to build your circuit. You can use 'shift+N' to hide or show these annotations.
#
# Implement the circuit below by using op-amp 1 (right one), resistors, and LEDs in your workspace. Hold off connecting $V_{\text{dd}}$ and $V_{\text{ss}}$ for now.
# <center>
# <img width='500px'
# src="images/blink_buffer_circuit_diagram_tinkercad.png">
# </center>
#
#
#
# #### Testing your circuit
#
# A microcontroller is a small and low-cost microcomputer, containing one or more CPUs, memory, and some peripheral circuits, which is widely used in modern electronic systems for controlling other portions.
#
# Tinkercad can simulate an Arduino microcontroller board, which is similar to the MSP430 Launchpad used in the hands-on lab. We will use the Arduino to generate a voltage square wave. You can click on the Code button to see the Scratch code the Arduino will be running. The code will turn on pins 13 and 12 for two seconds, and then turn them off for 2 seconds.
#
# Unlike some other microcontrollers, such as the MSP430 Launchpad, which has 3.3V logic, the Arduino has 5V logic. This means that for a logic HIGH signal, the Arduino's pins will output 5V (approximately, it won't be exactly 5V), while the Launchpad outputs 3.3V (approximately).
#
# The Arduino pin 13 generates a square wave with the following properties*:
#
# <center>
# <img width='700px'
# src="images/sqWave.png">
# </center>
#
#
#     - 0.25 Hz frequency (4 seconds cycle)
#     - 50% duty cycle. Duty cycle is the proportion of a cycle period for which the input is turned on, or logic HIGH.
#     - 5 volts peak-to-peak (Vpp). Peak-to-peak means the difference between the maximum and minimum of the wave.
#     - 2.5V offset (the wave is centered vertically around 2.5V)
#
# **Connect your op amp circuit with driving signal and voltage supplies**
# - Connect Pin 13 of your Arduino to the input ($V_{\text{in}}$) of your buffer circuit.
# - **Connect the ground of the Arduino to the negative power rail (-) (which should be connected to $V_{ss}$), so that the Arduino uses the same voltage reference as the other voltage supplies.**
# - **You need to power the op-amp with 5V in order for it to operate. Connect the correct DC voltages to $V_{\text{dd}}$ and $V_{\text{ss}}$.**
# - Use the multimeter to the measure the input of the circuit, $V_{\text{in}}$ (Coming from Pin 13 of the Arduino).
# - Run the simulation.
#     - When measuring the input signal generated by the Arduino, you may see that it does not actually reach 5V, even approximately. This is because of the "loading" effect of R1 and LED1. This pair of components is demanding more current than the Arduino pin can supply, so the output voltage of the pin drops below 5V.
#
# The final circuit should be similar to the circuit below:
# <center>
# <img width='900x'
# src="images/lab1_buffer_ckt.png">
# </center>

# %% [markdown]
# #### Voltage Gain
#
# The __Voltage Amplification (Av)__ or __Gain__ of a voltage amplifier is given by:
#
# $$A_v = \frac{\Delta V_{out}}{\Delta V_{in}} = \frac{V_{out}|_{V_{in}=V_{in,max}}-V_{out}|_{V_{in}=V_{in,min}}}{V_{in,max}-V_{in,min}}$$
#
# $A_v$ is a ratio of how much bigger is the output than the input, and so it has no units. Note that if the input is inverted, the gain is a __negative__ number.
#
# __Note__: $V_{out}|_x$ means $V_{out}$ given the condition $x$. For example, $V_{out}|_{V_{in}=V_{in,max}}$ means the output voltage of the op-amp when the input voltage is at its maximum.

# %% [markdown]
# <a id='part2'></a>
# ## <span>Questions:</span>

# %% [markdown]
# #### <span style="color:#075a04"> 1. Describe the blinking pattern of the two LEDs.
#     - A. They blink at the same rate and turn on and off at the same time.
#     - B. They blink at the same rate and one turns on while the other turns off.
#     - C. They blink at different rates and turn on and off randomly.
# < _YOUR ANSWER HERE_ >
#
#     A.

# %% [markdown]
# #### <span style="color:#075a04"> 2. What is the minimum voltage at the input ($V_{in}$) to your op amp circuit (in V)? Enter a numerical value with three decimal places (e.g. 3.142).
# < _YOUR ANSWER HERE_ >
#
#     0.00

# %% [markdown]
# #### <span style="color:#075a04"> 3. What is the maximum voltage at the input ($V_{in}$) to your op amp circuit (in V)? Enter a numerical value with two decimal places (e.g. 3.14).
# < _YOUR ANSWER HERE_ >
#
#     4.20

# %% [markdown]
# #### <span style="color:#075a04"> 4. What is the voltage at the op amp output ($V_{out}$) when the input ($V_{in}$) is at its minimum voltage (in V)? Enter a numerical value with three decimal places (e.g. 3.142).
# < _YOUR ANSWER HERE_ >
#
#     0.000

# %% [markdown]
# #### <span style="color:#075a04"> 5. What is the voltage at the op amp output ($V_{out}$) when the input ($V_{in}$) is at its maximum voltage (in V)? Enter a numerical value with two decimal places (e.g. 3.14).
# < _YOUR ANSWER HERE_ >
#
#     4.18

# %% [markdown]
# #### <span style="color:#075a04"> 6. What is the gain of this op amp circuit? Enter a numerical value with three decimal places (e.g. 3.142). Hint: You should use the above gain formula and measurement results to calculate the gain.
# < _YOUR ANSWER HERE_ >
#
#     0.995

# %% [markdown]
# #### <span style="color:#075a04"> 7. What is the voltage across $R_1$ when the input ($V_{in}$) is HIGH (in V)? Enter the absolute value with two decimal places (e.g. 3.14). Hint: You can use the multimeter to measure the voltage across $R_1$.
# < _YOUR ANSWER HERE_ >
#
#     2.20

# %% [markdown]
# #### <span style="color:#075a04"> 8. Without using the ammeter, calculate the current flowing through LED1 when the input ($V_{in}$) is HIGH (in mA). Enter the absolute value with two decimal places (e.g. 3.14).
# < _YOUR ANSWER HERE_ >,
#
#   19.10

# %% [markdown]
# #### <span style="color:#075a04"> 9. Measure the current coming out of the 5V power supply (in mA) when the input ($V_{in}$) is HIGH. Enter the absolute value with two decimal places (e.g. 3.14).
#
# < _YOUR ANSWER HERE_ >
#
# 11.50

# %% [markdown]
# ### Task 2:
#
# #### Wiring the op-amp as an inverter
#
# Another LM741 op amp (left one) will be used in this Task. Do NOT delete the circuit you built in the previous task.
#
# <center>
#     <img width="400px" src="images/LM741_pinout_updated.png">
# </center>
#
#
# Implement the circuit below by using op-amp 2 (left one), resistors, and LEDs in your workspace.
# <center>
# <img width='700px'
# src="images/inverter_circuit_diagram_tinkercad.png">
# </center>
#
#
#
# #### Testing your circuit
#
# The Arduino pin 12 generates the same square wave as pin 13.
#
# - Connect Pin 12 of your Arduino to the input ($V_{\text{in}}$) of your inverter circuit.
# - You need to power the op-amp with 5V in order for it to operate. Connect the correct DC voltages to $V_{\text{dd}}$ and $V_{\text{ss}}$.
# - Use the multimeter to the measure the input of the circuit $V_{\text{in}}$ (coming from Pin 12 of the Arduino).
# - Run the simulation.
#
# The final circuit should be similar to the circuit below:
# <center>
# <img width='900x'
# src="images/lab1_complete_ckt.png">
# </center>

# %% [markdown]
# <a id='part2'></a>
# ## <span>Questions:</span>

# %% [markdown]
# #### <span style="color:#075a04"> 10. Describe the blinking pattern of the two LEDs.
#     - A. They blink at the same rate and turn on and off at the same time.
#     - B. They blink at the same rate and one turns on while the other turns off.
#     - C. They blink at different rates and turn on and off randomly.
# < _YOUR ANSWER HERE_ >
#
#     C.

# %% [markdown]
# #### <span style="color:#075a04"> 11. What is the minimum voltage at the input ($V_{in}$) to your op amp circuit (in V)? Enter a numerical value with three decimal places (e.g. 3.142).
# < _YOUR ANSWER HERE_ >
#
#     1.68

# %% [markdown]
# #### <span style="color:#075a04"> 12. What is the maximum voltage at the input ($V_{in}$) to your op amp circuit (in V)? Enter a numerical value with two decimal places (e.g. 3.14).
# < _YOUR ANSWER HERE_ >
#
#     1.68

# %% [markdown]
# #### <span style="color:#075a04"> 13. What is the voltage at the op amp output ($V_{out}$) when the input ($V_{in}$) is at its minimum voltage (in V)? Enter a numerical value with two decimal places (e.g. 3.14).
# < _YOUR ANSWER HERE_ >
#
#     3.32

# %% [markdown]
# #### <span style="color:#075a04"> 14. What is the voltage at the op amp output ($V_{out}$) when the input ($V_{in}$) is at its maximum voltage (in V)? Enter a numerical value with three decimal places (e.g. 3.142).
# < _YOUR ANSWER HERE_ >
#
#     3.32

# %% [markdown]
# #### <span style="color:#075a04"> 15. What is the gain of this op amp circuit? Enter a numerical value with three decimal places (e.g. 3.142). Hint: You should use the above gain formula and measurement results to calculate the gain.
# < _YOUR ANSWER HERE_ >
#
#     0.000

# %% [markdown]
# #### <span style="color:#075a04"> 16. Please upload two screenshots of your final Tinkercad circuits, including both the circuit and schematic views. See the Getting Started with Tinkercad Guide for instructions on how to display the schematic view.

# %% [markdown]
# <a id='part3'></a>
# # <span style="color:#ba190f">CHECKOFF </span>
# -----
# ### For all students, submit your answers to Questions 1-15 to the Gradescope assignment "Lab 1: Introduction to Simulation." Submit your screenshots for Question 16 to the Gradescope assignment "Lab 1: Tinkercad Circuits." Lab 1 is due on Sunday, January 30 at 11:59pm. No late submissions will be accepted.
#
#
# ### Save this notebook somewhere you can access!
#
# We recommend making a shared Google Drive with your lab partner, since GitHub can be annoying with Jupyter notebooks. It's good to familiarize yourself with the user interface of Tinkercad and understand the basic functions of these circuits that you have built and analyzed.
#
#
# ### Great job finishing 16B Lab 1!
